# %% [markdown]
# Importamos librerias y leemos el csv

# %%
import pandas as pd
import numpy as np
print("Se importaron las librerias correctamente")
# Lee el archivo CSV
data = pd.read_csv("madrid-airbnb-listings-small.csv", sep = '	' )
# Out:
# Se importaron las librerias correctamente

# %% [markdown]
# Imprimimos por pantalla el dataset

# %%
columns = ["id", "host_id", "listing_url", "room_type", "neighbourhood_group_cleansed", "price", "cleaning_fee", "accommodates", "minimum_nights", "review_scores_rating", "latitude", "longitude", "is_location_exact"]

data = data[columns]
data
# Out:
#           id   host_id                           listing_url        room_type  \
# 0       6369     13660     https://www.airbnb.com/rooms/6369     Private room
# 1      21853     83531    https://www.airbnb.com/rooms/21853     Private room
# 2      24805    101471    https://www.airbnb.com/rooms/24805  Entire home/apt
# 3      24836    101653    https://www.airbnb.com/rooms/24836  Entire home/apt
# 4      26825    114340    https://www.airbnb.com/rooms/26825     Private room
# ..       ...       ...                                   ...              ...
# 995  2686592  13751801  https://www.airbnb.com/rooms/2686592     Private room
# 996  2701211   1650712  https://www.airbnb.com/rooms/2701211  Entire home/apt
# 997  2704499  13841663  https://www.airbnb.com/rooms/2704499  Entire home/apt
# 998  2706194   1843216  https://www.airbnb.com/rooms/2706194  Entire home/apt
# 999  2707743   5542111  https://www.airbnb.com/rooms/2707743  Entire home/apt
#
# ...

# %%
data = data.dropna()

# %%
# Reemplazar los símbolos $, . y , en la columna "price" por una cadena vacía y luego convertir la columna a tipo int
data["price"] = data["price"].str.replace("$", "")

# Reemplazar los símbolos $ y , en la columna "cleaning_fee" por una cadena vacía, rellenar los valores faltantes con 0 y luego convertir la columna a tipo int
data["cleaning_fee"] = data["cleaning_fee"].str.replace("$", "")
# Out:
# C:\Users\JOSE ANTONIO\AppData\Local\Temp\ipykernel_3328\1918794528.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data["price"] = data["price"].str.replace("$", "")
# C:\Users\JOSE ANTONIO\AppData\Local\Temp\ipykernel_3328\1918794528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["price"] = data["price"].str.replace("$", "")
# ...

# %%
# Out:
# C:\Users\JOSE ANTONIO\AppData\Local\Temp\ipykernel_3328\2631708641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["minimum_cost"] = data["price"] + data["cleaning_fee"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# ...

# %%
data["minimum_cost"] = data["price"] + data["cleaning_fee"]
data["minimum_cost_per_night"] = data["minimum_cost"] / data["minimum_nights"]
data["minimum_cost_per_person"] = data["minimum_cost_per_night"] / data["accommodates"]
# Out:
#           id                           listing_url       scrape_id  \
# 0       6369     https://www.airbnb.com/rooms/6369  20190919050215
# 1      21853    https://www.airbnb.com/rooms/21853  20190919050215
# 2      24805    https://www.airbnb.com/rooms/24805  20190919050215
# 3      24836    https://www.airbnb.com/rooms/24836  20190919050215
# 4      26825    https://www.airbnb.com/rooms/26825  20190919050215
# ..       ...                                   ...             ...
# 995  2686592  https://www.airbnb.com/rooms/2686592  20190919050215
# 996  2701211  https://www.airbnb.com/rooms/2701211  20190919050215
# 997  2704499  https://www.airbnb.com/rooms/2704499  20190919050215
# 998  2706194  https://www.airbnb.com/rooms/2706194  20190919050215
# 999  2707743  https://www.airbnb.com/rooms/2707743  20190919050215
#
#     last_scraped                                        description  \
# 0     2019-09-19  BETTER THAN A HOTEL.Upscale neighboorhood (Met...
# ...

# %%
data_2
# Out:
#           id                           listing_url       scrape_id  \
# 0       6369     https://www.airbnb.com/rooms/6369  20190919050215
# 1      21853    https://www.airbnb.com/rooms/21853  20190919050215
# 2      24805    https://www.airbnb.com/rooms/24805  20190919050215
# 3      24836    https://www.airbnb.com/rooms/24836  20190919050215
# 4      26825    https://www.airbnb.com/rooms/26825  20190919050215
# ..       ...                                   ...             ...
# 995  2686592  https://www.airbnb.com/rooms/2686592  20190919050215
# 996  2701211  https://www.airbnb.com/rooms/2701211  20190919050215
# 997  2704499  https://www.airbnb.com/rooms/2704499  20190919050215
# 998  2706194  https://www.airbnb.com/rooms/2706194  20190919050215
# 999  2707743  https://www.airbnb.com/rooms/2707743  20190919050215
#
#     last_scraped                                        description  \
# 0     2019-09-19  BETTER THAN A HOTEL.Upscale neighboorhood (Met...
# ...
